# %% [markdown]
# ---
# #STEP 0: Getting everything ready

# %% [markdown]
# First we need to create the right folders

# %%
import os
import cv2
general_videos_folder = "./videos/"
inputs_subfolder = "inputs/"
audio_subfolder = "audios/"
frames_subfolder = "frames/"
processed_frames_subfolder = "processed_frames/"
no_sound_videos_subfolder = "no_sound_videos/"
final_videos_subfolder = "final_videos/"
os.makedirs(general_videos_folder, exist_ok = True)
os.makedirs(f"{general_videos_folder}{inputs_subfolder}", exist_ok = True)
os.makedirs(f"{general_videos_folder}{audio_subfolder}", exist_ok = True)
os.makedirs(f"{general_videos_folder}{frames_subfolder}", exist_ok = True)
os.makedirs(f"{general_videos_folder}{processed_frames_subfolder}", exist_ok = True)
os.makedirs(f"{general_videos_folder}{no_sound_videos_subfolder}", exist_ok = True)
os.makedirs(f"{general_videos_folder}{final_videos_subfolder}", exist_ok = True)

# %% [markdown]
# Now please download a video (I will be using the video from [this link](https://drive.google.com/file/d/1AT1SlrUrzbEdQzr301CnlkCZ8DNC4ULf/view?usp=sharing)), and put it in the "videos/inputs/" folder.
#
# Give it a name (for me it was  **`the_office_auditions.mp4`** )
#
# Now run the following box with the name you gave it (do not include the .mp4 at the end)

# %%
filename = "news_base"

# %% [markdown]
# ---
# #STEP 1: Break a video into multiple *frames*

# %% [markdown]
# For this we use the cv2 library. This code is based on the [following link](https://www.geeksforgeeks.org/python-program-extract-frames-using-opencv/)

# %%
def video_to_frame(filename):
  os.makedirs(f"{general_videos_folder}{frames_subfolder}{filename}/", exist_ok = True)
  get_frame_path = lambda part: f"{general_videos_folder}{frames_subfolder}{filename}/frame-{part}.jpg" 
  vid_obj = cv2.VideoCapture(f"{general_videos_folder}{inputs_subfolder}{filename}.mp4")
  count = 0
  print(f"Total # of frames according to code {int(vid_obj.get(cv2.CAP_PROP_FRAME_COUNT))}")
  fps = vid_obj.get(cv2.CAP_PROP_FPS)
  print(f"Frames per second = {fps}")
  print("Now reading the frames... [This might take a while]")
  while True: 
    success, image = vid_obj.read() 
    if not success:
      break
    # Saves the frames with frame-count 
    cv2.imwrite(get_frame_path(count), image) 
    count += 1
  print(f"Total # frames accroding to loop = {count}")
  print(f"Succesfully wrote all the frames in the folder {general_videos_folder}{frames_subfolder}{filename}/")
  return fps

# %% [markdown]
# Apply function to our video

# %%
video_fps = video_to_frame(filename) #this function return the fps of such video
print(f"FPS returned from function: {video_fps}")
# Out:
# Total # of frames according to code 150
# Frames per second = 29.97002997002997
# Now reading the frames... [This might take a while]
# Total # frames accroding to loop = 150
# Succesfully wrote all the frames in the folder ./videos/frames/news_base/
# FPS returned from function: 29.97002997002997

# %% [markdown]
# Run the following **only** if you want to zip the frames folder for this video so that you can download them.

# %%
os.environ['FRAMES_FOLDER'] =  f"{general_videos_folder}{frames_subfolder}{filename}"
os.environ['ZIP_LOCATION'] = "."  #Will save it on the frames/ folder TODO: does this only add the frames/ folder?
# !zip -r $FRAMES_FOLDER $ZIP_LOCATION
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: videos/processed_frames/the_office_auditions/frame-7414.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-656.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-315.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-
jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-3313.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-562.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-3747.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-3738.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-266.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-5906.jpg (deflated 3%)
#   adding: videos/processed_frames/the_office_auditions/frame-572.jpg (deflated 3%)
#   adding: videos/processed_frames/the_office_auditions/frame-4148.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-2892.jpg (deflated 3%)
#   adding: videos/processed_frames/the_office_auditions/frame-1510.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-2729.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-8745.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-9899.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-9757.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-6012.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-868.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-9448.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-7731.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-9476.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-221.jpg (deflated 22%)
#   adding: videos/processed_frames/the_office_auditions/frame-150.jpg (deflated 22%)
#   adding: videos/processed_frames/the_office_auditions/frame-3982.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-958.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-5437.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-6293.jpg (deflated 3%)
#   adding: videos/processed_frames/the_office_auditions/frame-3615.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-6623.jpg (deflated 3%)
#   adding: videos/processed_frames/the_office_auditions/frame-3451.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-9873.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-5168.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-7818.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-9254.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-1309.jpg (deflated 3%)
#   adding: videos/processed_frames/the_office_auditions/frame-89.jpg (deflated 13%)
#   adding: videos/processed_frames/the_office_auditions/frame-5230.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-2120.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-8307.jpg (deflated 4%)
#   adding: videos/processed_frames/the_office_auditions/frame-3126.jpg (deflated 86%)
#   adding: videos/processed_frames/the_office_auditions/frame-3719.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-9874.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-8559.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-7101.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-8600.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-6064.jpg (deflated 3%)
#   adding: videos/processed_frames/the_office_auditions/frame-4213.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-720.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-10050.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-10086.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-9875.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-8903.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-9143.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-1559.jpg (deflated 3%)
#   adding: videos/processed_frames/the_office_auditions/frame-6448.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-2254.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-2876.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-6501.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-7864.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-1881.jpg (deflated 3%)
#   adding: videos/processed_frames/the_office_auditions/frame-7748.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-6821.jpg (deflated 3%)
#   adding: videos/processed_frames/the_office_auditions/frame-3447.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-2662.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-3201.jpg (deflated 24%)
#   adding: videos/processed_frames/the_office_auditions/frame-6141.jpg (deflated 4%)
#   adding: videos/processed_frames/the_office_auditions/frame-1240.jpg (deflated 3%)
#   adding: videos/processed_frames/the_office_auditions/frame-7233.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-3843.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-8968.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-3654.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-5125.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-2122.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-487.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-3782.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-9764.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-242.jpg (deflated 3%)
#   adding: videos/processed_frames/the_office_auditions/frame-5575.jpg (deflated 3%)
#   adding: videos/processed_frames/the_office_auditions/frame-3269.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-1615.jpg (deflated 4%)
#   adding: videos/processed_frames/the_office_auditions/frame-5837.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-7960.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-8962.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-2341.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-3371.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-2618.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-5046.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-1669.jpg (deflated 3%)
#   adding: videos/processed_frames/the_office_auditions/frame-9393.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-7068.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-7107.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-108.jpg (deflated 13%)
#   adding: videos/processed_frames/the_office_auditions/frame-2365.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-507.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-7492.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-488.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-5152.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-3566.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-4353.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-3835.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-8563.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-8535.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-1572.jpg (deflated 3%)
#   adding: videos/processed_frames/the_office_auditions/frame-6029.jpg (deflated 4%)
#   adding: videos/processed_frames/the_office_auditions/frame-9485.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-8311.jpg (deflated 4%)
#   adding: videos/processed_frames/the_office_auditions/frame-541.jpg (deflated 3%)
#   adding: videos/processed_frames/the_office_auditions/frame-3433.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-10170.jpg (deflated 85%)
#   adding: videos/processed_frames/the_office_auditions/frame-3974.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-49.jpg (deflated 13%)
#   adding: videos/processed_frames/the_office_auditions/frame-5461.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-8481.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-4164.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-6985.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-7727.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-5783.jpg (deflated 3%)
#   adding: videos/processed_frames/the_office_auditions/frame-5195.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-9347.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-5352.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-9681.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-4430.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-294.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-6105.jpg (deflated 3%)
#   adding: videos/processed_frames/the_office_auditions/frame-1271.jpg (deflated 3%)
#   adding: videos/processed_frames/the_office_auditions/frame-72.jpg (deflated 13%)
#   adding: videos/processed_frames/the_office_auditions/frame-4573.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-1739.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-3095.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-6742.jpg (deflated 3%)
#   adding: videos/processed_frames/the_office_auditions/frame-7394.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-7575.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-1484.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-5397.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-5209.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-3414.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-9008.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-6699.jpg (deflated 3%)
#   adding: videos/processed_frames/the_office_auditions/frame-7916.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-7633.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-622.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-6645.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-7635.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-6395.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-3877.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-5350.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-4856.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-9197.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-9068.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-8596.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-2649.jpg (deflated 3%)
#   adding: videos/processed_frames/the_office_auditions/frame-8873.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-4583.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-6184.jpg (deflated 3%)
#   adding: videos/processed_frames/the_office_auditions/frame-2621.jpg (deflated 3%)
#   adding: videos/processed_frames/the_office_auditions/frame-7260.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-6597.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-8095.jpg (deflated 3%)
#   adding: videos/processed_frames/the_office_auditions/frame-3849.jpg (deflated 1%)
#   adding: videos/processed_frames/the_office_auditions/frame-4833.jpg (deflated 2%)
#   adding: videos/processed_frames/the_office_auditions/frame-6679.jpg (deflated 2%)
#   adding: videos/no_sound_videos/ (stored 0%)
#   adding: videos/no_sound_videos/frames_combined_the_office_auditions.avi (deflated 5%)
#   adding: videos/audios/ (stored 0%)
#   adding: videos/audios/audio_from_the_office_auditions.mp3 (deflated 8%)
#   adding: videos/inputs/ (stored 0%)
#   adding: videos/inputs/the_office_auditions.mp4 (deflated 2%)
#   adding: sample_data/ (stored 0%)
#   adding: sample_data/anscombe.json (deflated 83%)
#   adding: sample_data/README.md (deflated 42%)
#   adding: sample_data/mnist_test.csv (deflated 88%)
#   adding: sample_data/california_housing_train.csv (deflated 79%)
#   adding: sample_data/mnist_train_small.csv (deflated 88%)
#   adding: sample_data/california_housing_test.csv (deflated 76%)

# %% [markdown]
# ---
# #STEP 2: Updating every frame

# %%
#For now, we will just copy the same images
os.environ['FRAME_FOLDER'] = f"{general_videos_folder}{frames_subfolder}{filename}"
os.environ['PROCESSED_FRAME_FOLDER'] = f"{general_videos_folder}{processed_frames_subfolder}{filename}"
# !cp -r $FRAME_FOLDER $PROCESSED_FRAME_FOLDER

# %% [markdown]
# ---
# #STEP 3: Outputting a video from several frames

# %% [markdown]
# Helper method that will help us make sure that names like 'frame-2' goes before 'frame-10'

# %%
def extract_number_from_image(filename, termination = ".jpg"):
    for i in range(len(filename)): #going through every character
        char = filename[i]
        if char.isdecimal():       #we found the beginning of the number we care about!
            last_decimal_index = len(filename) - len(termination) -1
            num_extracted = filename[i:last_decimal_index + 1]
            if num_extracted.isdecimal():
                return int(num_extracted)
            else:
                raise NameError("The filename {} should be of the form [PREFIX][NUMBER][TERMINATION]".format(filename))
    raise NameError("The filename {} didnt have any decimal digits".format(filename))

# %% [markdown]
# We do this in two parts
#
# 1.   First, we sort the images in the necessary folder. We use the `extract_number_from_image` function above to make sure that `frame-2.jpg` goes before `frame-10.jpg`
# 2.   For every image of the frame, we get its raw value by calling `cv2.imread()` and we add each of them to a `VideoWriter` object previously created.
# > We create this object by using the size of the first image.

# %%
video_fps = 30 #just for now, dont forget to delete

# %%
def frames_to_video(filename):
  in_folder = f"{general_videos_folder}{processed_frames_subfolder}"
  all_elements = os.listdir(f"{in_folder}{filename}/")
  all_images = list(filter(lambda name: name.endswith(".jpg"), all_elements)) #only keeping the images
  all_images.sort(key = extract_number_from_image) #to order them by number, and not lexicographically
  print("Going through all frames")
  is_first = True
  for image in all_images:
    image_path = f"{in_folder}{filename}/{image}"
    print(f"Image path: {image_path}")
    frame = cv2.imread(image_path)
    height, width, layers = frame.shape
    size = (width,height)
    if is_first:
      out_path = f"{general_videos_folder}{no_sound_videos_subfolder}frames_combined_{filename}.avi" #TODO: find fourcc of MP4 files
      print(f"Creating a new video file at {out_path} with fps ={video_fps} and size {size}")
      fourcc = cv2.VideoWriter_fourcc(*'DIVX')
      out = cv2.VideoWriter(out_path,fourcc, video_fps, size) #creating a video to store the frames
      is_first = False
    out.write(frame)
  out.release()
  cv2.destroyAllWindows() 
  print("Finished converting to video!")

# %%
def frames_to_video_helper():
  in_folder = f"{general_videos_folder}{processed_frames_subfolder}"
  all_elements = os.listdir(f"{in_folder}{filename}/")
  all_images = list(filter(lambda name: name.endswith(".jpg"), all_elements)) #only keeping the images
  all_images.sort(key = extract_number_from_image) #to order them by number, and not lexicographically
  print("Going through all frames")
  is_first = True
  for image in all_images:
    image_path = f"{in_folder}{filename}/{image}"
    print(f"Image path: {image_path}")
    frame = cv2.imread(image_path)
    height, width, layers = frame.shape
    size = (width,height)
    if is_first:
      out_path = f"{general_videos_folder}{no_sound_videos_subfolder}frames_combined_{filename}.avi" #TODO: find fourcc of MP4 files
      print(f"Creating a new video file at {out_path} with fps ={video_fps} and size {size}")
      fourcc = cv2.VideoWriter_fourcc(*'DIVX')
      out = cv2.VideoWriter(out_path,fourcc, video_fps, size) #creating a video to store the frames
      is_first = False
    out.write(frame)
  out.release()
  cv2.destroyAllWindows() 
  print("Finished converting to video!")

# %% [markdown]
# Now lets convert the processed frames we got into a sweet video (but with no sound)

# %%
frames_to_video(filename)
# Out:
# Going through all frames
# Image path: ./videos/processed_frames/the_office_auditions/frame242.jpg
# Creating a new video file at ./videos/no_sound_videos/frames_combined_the_office_auditions.avi with fps =30 and size (496, 360)
# Image path: ./videos/processed_frames/the_office_auditions/frame243.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame244.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame245.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame246.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame247.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame248.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame249.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame250.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame251.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame252.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame253.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame254.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame255.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame256.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame257.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame258.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame259.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame260.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame261.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame262.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame263.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame264.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame265.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame266.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame267.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame268.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame269.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame270.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame271.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame272.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame273.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame274.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame275.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame276.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame277.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame278.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame279.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame280.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame281.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame282.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame283.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame284.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame285.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame286.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame287.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame288.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame289.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame290.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame291.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame292.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame293.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame294.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame295.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame296.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame297.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame298.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame299.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame300.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame301.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame302.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame303.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame304.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame305.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame306.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame307.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame308.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame309.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame310.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame311.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame312.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame313.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame314.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame315.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame316.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame317.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame318.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame319.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame320.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame321.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame322.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame323.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame324.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame325.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame326.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame327.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame328.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame329.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame330.jpg
# Image path: ./videos/processed_frames/the_office_auditions/frame331.jpg
# Finished converting to video!

# %% [markdown]
# ---
#
# #STEP 4: Extract the audio from original video

# %% [markdown]
# Now, even though we just created a video out of our processed frames, we lost the sound in the process, so we can try to extract the audio from the original video as follows:

# %%
from moviepy.editor import AudioFileClip
def extract_audio(filename):
  audio_path = f"{general_videos_folder}{inputs_subfolder}{filename}.mp4"
  audio = AudioFileClip(audio_path)
  audio.write_audiofile(f"{general_videos_folder}{audio_subfolder}audio_from_{filename}.mp3")

# %% [markdown]
# Now lets extract the audio of the video we created first

# %%
extract_audio(filename)
# Out:
# [MoviePy] Writing audio in ./videos/audios/audio_from_the_office_auditions.mp3
# 100%|██████████| 7520/7520 [00:08<00:00, 917.09it/s]
# [MoviePy] Done.

# %% [markdown]
# ---
#
# #STEP 5: Add the audio to our processed video

# %% [markdown]
# We are so close! Now we only need a way to combine the video we created in `Step #3` and the original audio we extracted in `Step #4`

# %%
from moviepy.editor import VideoFileClip
def add_audio_to_processed_video(filename):
  video_no_sound_path = f"{general_videos_folder}{no_sound_videos_subfolder}frames_combined_{filename}.avi"
  video_no_sound = VideoFileClip(video_no_sound_path)

  video_final_path = f"{general_videos_folder}{final_videos_subfolder}final_{filename}.mp4"
  audio_path = f"{general_videos_folder}{audio_subfolder}audio_from_{filename}.mp3"
  video_no_sound.write_videofile(video_final_path, audio = audio_path)

# %% [markdown]
# And now ... **drumrolls**... the final step.

# %%
add_audio_to_processed_video(filename)
# Out:
# [MoviePy] >>>> Building video ./videos/final_videos/final_the_office_auditions.mp4
# [MoviePy] Writing video ./videos/final_videos/final_the_office_auditions.mp4
# 100%|██████████| 10228/10228 [01:40<00:00, 102.04it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ./videos/final_videos/final_the_office_auditions.mp4

# %% [markdown]
# Now you can see the video in `videos/final_videos/`. Please download it to make sure that:
#
#
# 1.   The audio is in sync with the video (this is why we needed to get the fps of the original video in `Step #`1)
# 2.   The frames are in the order they appeared initially
# 3.   The video feels *smooth* , so that it's not noticeable that this was completely done in Python!
# 4. For now, since in `Step #2` we only copied the frames as they were, this output video should be **identical** to the original.

# %% [markdown]
# **The End.**
#
# ---
